# %%
import tifffile as tiff
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
baseline = tiff.imread('./data/baseline.tiff')
detrended = tiff.imread('./data/detrended.tiff')
data = baseline + detrended[600]
data
# Out:
# array([[30170490, 30377799, 30376781, ..., 17071227, 17063754, 17654371],
#        [30163667, 30369469, 30368342, ..., 16998219, 16927281, 17433952],
#        [30161978, 30367101, 30365954, ..., 16969596, 16789583, 17235506],
#        ...,
#        [30164187, 30368953, 30367155, ..., 24754454, 24716908, 24695444],
#        [30166387, 30371684, 30370152, ..., 24774868, 24735935, 24714034],
#        [30171596, 30379699, 30378935, ..., 24785796, 24746167, 24724277]],
#       dtype=uint32)

# %%
# create data points
x = range(data.shape[1])
y = range(data.shape[0])
# create grid
X, Y = np.meshgrid(x, y)
Z = data
# create figure container
fig = plt.figure(figsize=(9, 6))
ax = plt.axes(projection = '3d')
ax.view_init(90, -90)
# 3d contour plot
ax.contour3D(X, Y, Z, 100, cmap = 'viridis')
# set labels
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('height')
# save figure
plt.savefig('3d_contour.png', dpi = 300)

# 2d plot
plt.figure()
plt.title('2D view')
p = plt.imshow(data)
plt.colorbar(p)
plt.show()
